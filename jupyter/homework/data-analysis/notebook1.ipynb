# %% [markdown]
# ![](https://pic4.zhimg.com/80/v2-406d1e6a28e113801a057d8104d81067_720w.jpg)

# %%
import  numpy as np
import  pandas as pd
import matplotlib.pyplot as plt

# %%
fig = plt.figure(num=1,figsize=(4,4)) # 生成画布
ax1 = fig.add_subplot(221)
ax1.plot([1,2,3,4],[1,2,3,4])
ax2=fig.add_subplot(222)
ax2.plot([1,2,3,4],[2,2,3,4])
ax3=fig.add_subplot(223)
ax3.plot([1,2,3,4],[1,2,2,4])
ax4=fig.add_subplot(224)
ax4.plot([1,2,3,4],[1,2,3,3])

# %%
import  matplotlib.gridspec as gridspace
fig = plt.figure(num=1,figsize=(6,6))# 依旧指定num=1的画布。下面的ax绑定的就是这个
gs = gridspace.GridSpec(3,3)
ax1=fig.add_subplot(gs[0,:])#选定网格
ax1.plot([1,2,3,4],[1,2,3,4])

ax2=fig.add_subplot(gs[1,:-1])
ax2.plot([1,2,3,4],[1,2,3,4])

ax3=fig.add_subplot(gs[1:,-1])
ax3.plot([1,2,3,4],[1,2,3,4])

ax4=fig.add_subplot(gs[2,0])
ax4.plot([1,2,3,4],[1,2,3,4])

ax5=fig.add_subplot(gs[2,1])
ax5.plot([1,2,3,4],[1,2,3,4])
