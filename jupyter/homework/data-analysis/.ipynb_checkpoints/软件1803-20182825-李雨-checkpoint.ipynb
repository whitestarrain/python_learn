# %% [markdown]
# # 任务总览
# - 单因素统计
#     - 公园
#         - 分析公园种类的数量分布
#         - 画出公园在美国的分布
#     - 人口
#         - 分析人口的变化
#     - 汽油
#         - 分析汽油价格的变化
#     - 访问量
#         - 分析随着时间公园总访问量的变化
# - 多因素统计
#     - 公园
#         > 贡献度：指定类型公园总访问量<br/>
#         > 吸引度：指定类型公园每一所每年的平均访问量
#         -  分析不同类型公园的贡献度和吸引读
#         - 分析最吸引人的5种公园的吸引度变化
#     - 人口
#         - 分析总人口变化与总访问量的关系。
#     - 汽油
#         - 分析访问量变化和油价变化的关系。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
parks = pd.read_csv("./data/All National Parks Visitation 1904-2016.csv")
gas = pd.read_csv("./data/gas_price.csv")
locations = pd.read_csv("./data/locations.csv")
pop = pd.read_csv("./data/state_pop.csv")

# 在后面分析中发现parks中有年份为Total的记录，应该在此处删除删除

# %% [markdown]
# # 单因素统计

# %% [markdown]
# ## 分析随着时间公园总访问量的变化

# %%
print((parks["Visitors"].isnull()).sum())
print((parks["Visitors"] == 0).sum())
# 公园访问量为null的有4个
# 公园访问量为0的记录有180个。
# Out:
# 4
# 180

# %%
parks[parks["Visitors"].isnull()]
# 发现为NaN的，YearRaw为Total
# Out:
#     Created By  Measure Selector                  Year   Date Edit  \
# 300      Lands                 1  1/1/2000 12:00:00 AM   8/13/2015
# 308      Lands                 1  1/1/2000 12:00:00 AM  10/15/2015
# 337      Lands                 1  1/1/2000 12:00:00 AM   4/26/2016
# 369      Lands                 1  1/1/2000 12:00:00 AM   9/12/2016
#
#                                              ScrapeURL  \
# 300  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 308  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 337  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 369  https://irma.nps.gov/Stats/SSRSReports/Park%20...
#
#                                              GIS Notes  Gnis Id      Geometry  \
# 300  Lands - http://landsnet.nps.gov/tractsnet/docu...  2767391       POLYGON
# 308  Lands - http://landsnet.nps.gov/tractsnet/docu...  2766708  MULTIPOLYGON
# 337  Lands - http://landsnet.nps.gov/tractsnet/docu...  2035517       POLYGON
# 369  Lands - http://landsnet.nps.gov/tractsnet/docu...  2766905       POLYGON
#
#                                               Metadata  Number of Records  \
# 300  http://nrdata.nps.gov/programs/Lands/HONO_meta...                  1
# 308  http://nrdata.nps.gov/programs/Lands/MIIN_meta...                  1
# 337  http://nrdata.nps.gov/programs/Lands/VALL_meta...                  1
# 369  http://nrdata.nps.gov/programs/Lands/PULL_meta...                  1
#
#            Parkname Region State Unit Code                         Unit Name  \
# 300      Honouliuli     PW    HI      HONO      Honouliuli National Monument
# 308        Minidoka     PW    WA      MIIN   Minidoka National Historic Site
# 337  Valles Caldera     IM    NM      VALL  Valles Caldera National Preserve
# 369         Pullman     MW    IL      PULL         Pullman National Monument
#
#                             Unit Type  Visitors YearRaw
# 300                 National Monument       NaN   Total
# 308            National Historic Site       NaN   Total
# 337  Valles Caldera National Preserve       NaN   Total
# 369                 National Monument       NaN   Total

# %%
# 应该是数据集本身有统计。此处不再会重新进行统计，所以删除YearRaw为Total的记录
parks = parks.drop(parks[parks["YearRaw"] == "Total"].index.values)

# %%
# 对于访问量为0的记录，因为不清楚原因，所以这里会画填补0值，以及不填0值的两张图

# %%
# 0值记录的年份
(parks[parks["Visitors"] == 0])['YearRaw'].unique()
# Out:
# array(['1941', '1991', '1990', '2016', '2015', '2014', '2013', '2012',
#        '2010', '2007', '2005', '2003', '2004', '2001', '2000', '1999',
#        '1997', '1995', '1996', '1994', '1993', '1947', '1988', '1946',
#        '1945', '1944', '1943', '1942', '1982', '1981', '1980', '1965'],
#       dtype=object)

# %%
# 0值记录的州
(parks[parks["Visitors"] == 0])['State'].unique()
# Out:
# array(['WA', 'MD', 'SC', 'NY', 'GA', 'MO', 'DC', 'ND', 'VA', 'MS', 'AK',
#        'NJ', 'AS', 'MA', 'UT', 'CA', 'NM', 'NE', 'OH', 'FL', 'SD', 'OR',
#        'MT'], dtype=object)

# %%
# 通过每年所有公园的访问量进行填补
v_mean = parks.loc[:, ["YearRaw", "Visitors"]].groupby("YearRaw").mean()
v_mean.head(3)
# Out:
#              Visitors
# YearRaw
# 1904     20115.000000
# 1905     23492.333333
# 1906      4367.000000

# %%
def set_mean(x, v_mean):
    x['Visitors'] = v_mean.loc[x['YearRaw']]
    return x['Visitors']


parks_n0 = (parks.loc[parks["Visitors"] == 0, ["Visitors", "YearRaw"]].apply(
    set_mean, args=(v_mean,), axis=1)).combine_first(parks)
# 使用combine_first 通过id覆盖parks中为0的

# %%
# 去完0
(parks_n0["Visitors"] == 0).sum()
# Out:
# 0

# %%
# 以万为单位
p2 = (pd.concat([parks.loc[:, ["YearRaw"]], parks.loc[:, [
      "Visitors"]]/10000], axis=1)).groupby("YearRaw").sum()
p3 = (pd.concat([parks_n0.loc[:, ["YearRaw"]], parks_n0.loc[:, [
      "Visitors"]]/10000], axis=1)).groupby("YearRaw").sum()

# %%
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False
figure = plt.figure(num=1, figsize=(20, 8), dpi=80)
plt.plot(range(len(p3.index)), p3, "b-", label="去0")
plt.plot(range(len(p2.index)), p2, "r-", label="不去0")
plt.grid(alpha=0.6)
plt.legend()
plt.xticks(range(len(p3.index))[::5], p3.index[::5])
plt.xlabel("年份", fontsize=14)
plt.ylabel("人数/万人", fontsize=14)
plt.title("公园总访问量（去0）", fontsize=14)
plt.show()

# 可以发现补0和不补会有非常小的区别，
# 但因为0值是缺失还是本身就是0无从考证
# 在下面的分析中会针对不同情况进行分析

# %% [markdown]
# ## 分析公园种类的数量分布

# %%
parks.loc[:, ["Gnis Id", "Unit Type"]].isnull().sum()
# 不存在null
# Out:
# Gnis Id      0
# Unit Type    0
# dtype: int64

# %%
park_types = parks.loc[:, ["Gnis Id", "Unit Type"]
                       ].groupby("Unit Type").count()

# %%
park_types.head(3)
# Out:
#                                   Gnis Id
# Unit Type
# Ecological and Historic Preserve       25
# International Historic Site             4
# National Battlefield                  847

# %%
plt.figure(num=1, figsize=(20, 8))
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False
x = range(len(park_types))
bar1 = plt.bar(x, park_types["Gnis Id"], width=0.6)
plt.grid(axis="y", alpha=0.6)
names = park_types.index.str.replace(" ", "\n")
i = 0
# 标注总数量
for b in bar1:
    height = b.get_height()
    plt.text(b.get_x() + b.get_width() / 2, height + 1,
             str(height), ha='center', va='bottom')
# 标注种类名称
for b in bar1:
    height = b.get_height()
    plt.text(b.get_x() + b.get_width() / 2, height + 200,
             names[i], ha='center', va='bottom', fontsize='x-small')
    i += 1
plt.ylim(0, 6000)
plt.ylabel("数量", fontsize=14)
plt.xlabel("公园种类", fontsize=14)
plt.title('各种类公园的数量', fontsize=14)
plt.show()

# %% [markdown]
# ## 画出公园在美国的分布

# %%
# 用来画点的函数
def point_park(a, m, p):
    xpt, ypt = m(a[0], a[1])
    m.plot(xpt, ypt, p, markersize=3)

# %%
plt.figure(figsize=(20, 8))
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False
m = Basemap(projection='mill',
            llcrnrlat=15,
            llcrnrlon=-180,
            urcrnrlat=75,
            urcrnrlon=-20,
            resolution='l')
# llcrnrlat - 左下角的纬度
# llcrnrlon - 左下角的经度
# urcrnrlat - 右上角的纬度
# urcrnrlon - 右上角的经度
# 此外，坐标需要转换，其中西经和南纬坐标是负值，北纬和东经坐标是正值。
m.drawcoastlines()
m.drawcountries(linewidth=1)
m.drawcounties(color='darkred')
# m.etopo()
locations.loc[:, ["lon", "lat"]].apply(point_park, axis=1, args=(m, 'g^'))
plt.title('公园的分布', fontsize=14)
plt.show()

# %%
# 带上地形分布等等
plt.figure(figsize=(20, 8))
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False
m = Basemap(projection='mill',
            llcrnrlat=15,
            llcrnrlon=-180,
            urcrnrlat=75,
            urcrnrlon=-20,
            resolution='l')
# llcrnrlat - 左下角的纬度
# llcrnrlon - 左下角的经度
# urcrnrlat - 右上角的纬度
# urcrnrlon - 右上角的经度
# 此外，坐标需要转换，其中西经和南纬坐标是负值，北纬和东经坐标是正值。
m.drawcoastlines()
m.drawcountries(linewidth=2)
m.drawcounties(color='darkred')
m.etopo(scale=0.5)  # 降低分辨率
locations.loc[:, ["lon", "lat"]].apply(point_park, axis=1, args=(m, 'b^'))
plt.title('公园的分布', fontsize=14)
plt.show()

# %% [markdown]
# ## 分析人口的变化

# %%
# 一共有116年的数据
print(len(pop["year"].unique()))
# Out:
# 116

# %%
# 50年
# 1900-1949年有的记录没有人口数据
print(len(pop["year"][pop["pop"].isnull()].unique()))
pop["year"][pop["pop"].isnull()].unique()
# Out:
# 50
# array([1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910,
#        1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921,
#        1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932,
#        1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943,
#        1944, 1945, 1946, 1947, 1948, 1949], dtype=int64)

# %%
print(pop["pop"].isnull().sum())  # 100条数据
print(pop["state"][pop["pop"].isnull()].unique())  # 一共俩州
# Out:
# 100
# ['AK' 'HI']

# %%
# 一共100条记录没有数据
# 100条数据是50年间，两个州的
# 预计两个州个各50年的人口没有统计，进行验证
print((pop["pop"][pop["state"] == 'AK']).isnull().sum())
print((pop["pop"][pop["state"] == 'HI']).isnull().sum())
# 正确
# Out:
# 50
# 50

# %%
# 在此处为了降低缺失值的影响，可以通过其他州平均人数进行填充
# 而目的为统计人口变化
# 所以可以变换为统计所有州平均人数变化
p1 = pop.dropna(axis=0).groupby("year").aggregate({
    "state": len,
    "pop": np.sum
})
p_avg = p1["pop"]/p1["state"]
p_avg.head(3)
# Out:
# year
# 1900    1.552959e+06
# 1901    1.583429e+06
# 1902    1.615510e+06
# dtype: float64

# %%
plt.figure(num=1, figsize=(20, 8), dpi=80)
plt.grid(alpha=0.5)
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False
plt.xlabel("年份", fontsize=14)
plt.ylabel("州平均人口(万人)", fontsize=14)
plt.plot(p_avg.index, (p_avg/10000).astype("float"), 'o-')
plt.title("平均人口统计", fontsize=14)
plt.xticks(range(np.min(p_avg.index), np.max(
    p_avg.index)+1, 5), p_avg.index[::5])
plt.show()

# %% [markdown]
# ## 分析汽油价格的变化

# %%
gas.info()
# 没有缺失数据
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          87 non-null     int64
#  1   gas_current   87 non-null     float64
#  2   gas_constant  87 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 2.2 KB

# %%
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False
plt.figure(num=1, figsize=(20, 8), dpi=80)
plt.grid(alpha=0.5)
plt.plot(range(len(gas)), gas["gas_current"])
plt.xticks(range(len(gas))[::5], gas["year"][::5])
plt.xlabel("年份", fontsize=14)
plt.ylabel("油价(dollar/gallon)", fontsize=14)
plt.title('油价变化', fontsize=14)
plt.show()

# %% [markdown]
# # 多因素统计

# %% [markdown]
# ## 不同类型公园的贡献度和吸引度

# %%
# 因为数量相差很大，所以应该使用每个种类的平均访问量
# 因为如果一个访问量为0会严重影响平均，不管是数据错误还是公园闭馆等情况都不能使用为0的记录
# 所以这里不会考虑为0的记录

def wan_sum(x):  # 以万为单位
    return np.sum(x)/10000


parks_d0 = parks[parks['Visitors'] != 0]
park_v_t = parks_d0.loc[:, ["Visitors", "Unit Type", "Gnis Id"]].groupby(
    "Unit Type").aggregate({'Visitors': wan_sum, 'Gnis Id': len})

# %%
park_v_t.head(3)
# Out:
#                                     Visitors  Gnis Id
# Unit Type
# Ecological and Historic Preserve   1801.8607       25
# International Historic Site           4.8711        4
# National Battlefield              15028.7669      836

# %%
park_v_t_avg = np.round(park_v_t['Visitors']/park_v_t['Gnis Id'], 3)

# %%
plt.figure(num=1, figsize=(22, 16))
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False

plt.subplot(211)
x = range(len(park_v_t_avg))
bar1 = plt.bar(x, park_v_t_avg, width=0.6)
plt.grid(axis="y", alpha=0.6)
names = park_v_t_avg.index.str.replace(" ", "\n")
i = 0
# 标注总数量
for b in bar1:
    height = b.get_height()
    plt.text(b.get_x() + b.get_width() / 2, height + 1,
             str(height), ha='center', va='bottom')
# 标注种类名称
for b in bar1:
    height = b.get_height()
    plt.text(b.get_x() + b.get_width() / 2, height + 30,
             names[i], ha='center', va='bottom', fontsize=8)
    i += 1
plt.ylim(0, 1000)
plt.ylabel("平均访问量(万人次)", fontsize=14)
plt.xlabel("公园种类", fontsize=14)
plt.title('各种类公园平均每年每个公园访问人数(吸引力)', fontsize=14)


# 总访问量
plt.subplot(212)
x = range(len(park_v_t))
bar1 = plt.bar(x, np.round(park_v_t['Visitors']/100, 2), width=0.6)  # 调整为百万
plt.grid(axis="y", alpha=0.6)
names = park_v_t.index.str.replace(" ", "\n")
i = 0
# 标注总数量
for b in bar1:
    height = b.get_height()
    plt.text(b.get_x() + b.get_width() / 2, height + 1,
             str(height), ha='center', va='bottom')
# 标注种类名称
for b in bar1:
    height = b.get_height()
    plt.text(b.get_x() + b.get_width() / 2, height + 170,
             names[i], ha='center', va='bottom', fontsize=8)
    i += 1
plt.ylim(0, 4000)
plt.ylabel("平均总访问量(百万人次)", fontsize=14)
plt.xlabel("公园种类", fontsize=14)
plt.title('各种类公园平均总访问量(贡献度)', fontsize=14)

plt.show()

# %% [markdown]
# ## 分析访问量最高的5种公园访问量变化

# %%
most_popular_5 = park_v_t.sort_values(ascending=False,by='Visitors')[0:5].index

# %%
most_popular_5
# Out:
# Index(['National Park', 'National Recreation Area', 'Parkway',
#        'National Historical Park', 'National Memorial'],
#       dtype='object', name='Unit Type')

# %%
# 得到每一个公园类型每年的访问量
parks_type_var = parks[['Visitors', 'YearRaw', 'Unit Type']].pivot_table(
    'Visitors', index='YearRaw', columns='Unit Type', aggfunc=wan_sum)  # 这里依旧使用万人次进行统计
parks_type_var = parks_type_var.round(2)
parks_type_var.tail(3)
# Out:
# Unit Type  Ecological and Historic Preserve  International Historic Site  \
# YearRaw
# 2014                                 112.13                         1.16
# 2015                                 123.94                         1.26
# 2016                                 114.85                         1.39
#
# Unit Type  National Battlefield  National Battlefield Park  \
# YearRaw
# 2014                     224.89                     286.80
# 2015                     226.46                     297.02
# 2016                     247.15                     330.64
#
# Unit Type  National Battlefield Site  National Historic Site  \
# YearRaw
# 2014                             NaN                  997.97
# 2015                             NaN                 1002.80
# 2016                             NaN                 1107.76
#
# Unit Type  National Historical Park  National Historical Park and Preserve  \
# YearRaw
# 2014                        2960.43                                  44.55
# 2015                        2961.60                                  40.56
# 2016                        3193.09                                  43.84
#
# Unit Type  National Lakeshore  National Memorial  ...  \
# YearRaw                                           ...
# 2014                   376.67            3283.10  ...
# 2015                   413.17            3701.22  ...
# 2016                   434.30            3799.80  ...
#
# Unit Type  National River and Recreation Area  National Scenic River  \
# YearRaw
# 2014                                    68.55                   9.19
# 2015                                    77.08                  10.48
# 2016                                    94.17                  10.80
#
# Unit Type  National Scenic Riverway  National Seashore  Other Designation  \
# YearRaw
# 2014                         196.80            1854.67             466.49
# 2015                         190.11            1870.62             490.74
# 2016                         194.97            1979.72             529.28
#
# Unit Type    Park  Parkway  Scenic and Recreational River  War in the Pacific  \
# YearRaw
# 2014       275.30  1978.82                          23.08               26.62
# 2015       275.59  2084.04                          24.32               32.25
# 2016       282.32  2106.69                          26.44               48.90
#
# Unit Type  Wild and Scenic River
# YearRaw
# 2014                       21.61
# 2015                       21.46
# 2016                       23.19
#
# [3 rows x 29 columns]

# %%
parks_type_var.isnull().sum()
# 因为公园可能建立时间较晚，或者废弃时间较早，所以会有很多公园在一定时间段内没有访问数据
# Out:
# Unit Type
# Ecological and Historic Preserve          88
# International Historic Site              109
# National Battlefield                      30
# National Battlefield Park                 30
# National Battlefield Site                 71
# National Historic Site                    32
# National Historical Park                  16
# National Historical Park and Preserve     33
# National Lakeshore                        69
# National Memorial                         30
# National Military Park                    30
# National Monument                          7
# National Park                              0
# National Parkway                          62
# National Preserve                         27
# National Recreation Area                  33
# National Recreation River                100
# National Reserve                          88
# National River                            69
# National River and Recreation Area        84
# National Scenic River                     89
# National Scenic Riverway                  66
# National Seashore                         51
# Other Designation                         47
# Park                                      41
# Parkway                                   37
# Scenic and Recreational River             76
# War in the Pacific                        81
# Wild and Scenic River                     81
# dtype: int64

# %%
min_year = int(parks_type_var.index.min())
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False
plt.figure(num=1, figsize=(10, 8), dpi=80)

for i in most_popular_5:
    temp = parks_type_var[i][parks_type_var[i].notnull()]
    # print(temp.index.min(),temp.index.max())
    # print(len(temp))
    plt.plot(temp.index.astype('int')-min_year, temp, label=i)
for i in parks_type_var.columns:
    if i not in most_popular_5:
        temp = parks_type_var[i][parks_type_var[i].notnull()]
        plt.plot(temp.index.astype('int')-min_year, temp, label=i,c='#79979A',alpha=0.5)
        
    
plt.grid(alpha=0.5)
plt.xticks(range(len(parks_type_var.index))[::5],parks_type_var.index[::5])
plt.xlabel('年份', fontsize=14)
plt.ylabel('总人次/万人', fontsize=14)
plt.legend(most_popular_5)
plt.title('每种公园年总访问量随年份变化', fontsize=14)
plt.show()

# %% [markdown]
# ## 分析人口变化与访问量的关系。

# %%
len(pop['state'].unique())
#  一共有51个州，不可能每个州都分析一遍，所以这里比较总人口的变化与总访问量的变化
# 因为是总访问人次，所以此处不会处理0值
# Out:
# 51

# %%
parks_v_p = parks[['YearRaw', 'Visitors']].groupby('YearRaw').sum()
parks_v_p.head(3)
# Out:
#          Visitors
# YearRaw
# 1904     120690.0
# 1905     140954.0
# 1906      30569.0

# %%
pop_a = pop[['year', 'pop']].groupby('year').sum()
pop_a.head(3)
# Out:
#              pop
# year
# 1900  76095000.0
# 1901  77588000.0
# 1902  79160000.0

# %%
# 为了比较两者趋势，这里进行归一化
v_max = parks_v_p['Visitors'].max()
v_min = parks_v_p['Visitors'].min()
parks_v_p = (parks_v_p['Visitors']-v_min)/(v_max-v_min)

p_max = pop['pop'].max()
p_min = pop['pop'].min()
pop_a = (pop_a['pop']-p_min)/(v_max-v_min)

# %%
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False
plt.figure(num=1, figsize=(20, 8), dpi=80)
plt.grid(alpha=0.5)
plt.plot(range(len(parks_v_p)), parks_v_p, label='访问量变化')
plt.plot(range(len(pop_a)), pop_a, label='人口变化')
plt.xticks(range(len(pop_a))[::5], pop_a.index[::5])
plt.xlabel('年份', fontsize=14)
plt.ylabel('归一化后数据', fontsize=14)
plt.legend()
plt.title('人口变化和访问量变化', fontsize=14)
plt.show()

# %% [markdown]
# ## 分析访问量变化和油价变化的关系。

# %%
# 最早只有1929年的
gas['year'].min(), gas['year'].max()
# Out:
# (1929, 2015)

# %%
# 截取1929-2015的访问人次变化
parks_v_p_x = parks_v_p.loc['1929':'2015']
parks_v_p_x.head(1)
# Out:
# YearRaw
# 1929    0.009077
# Name: Visitors, dtype: float64

# %%
# gas的归一化
g_max = gas['gas_current'].max()
g_min = gas['gas_current'].min()
gas_g = (gas['gas_current']-g_min)/(g_max-g_min)

# %%
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False
plt.figure(num=1, figsize=(20, 8), dpi=80)
plt.grid(alpha=0.5)
plt.plot(range(len(parks_v_p_x)), parks_v_p_x, label='访问量变化')
plt.plot(range(len(gas_g)), gas_g, label='油价变化')
plt.xticks(range(len(parks_v_p_x))[::5], parks_v_p_x.index[::5])
plt.xlabel('年份', fontsize=14)
plt.ylabel('归一化后数据', fontsize=14)
plt.legend()
plt.title('油价变化和访问量变化', fontsize=14)
plt.show()
